# %%
2+3
# addition
2+2
# Out:
# 4

# %%
# subtraction
4-6
# Out:
# -2

# %%
# Multiplecation
2*2
# Out:
# 4

# %%
# Division
5/3
# Out:
# 1.6666666666666667

# %%
# floor division
5//3
# Out:
# 1

# %%
# Exponentition 

2**3
# Out:
# 8

# %%
# Modulus (it is Remainder )
5%6
# Out:
# 5

# %%
4%2
# Out:
# 0

# %%
3%2
# Out:
# 1
